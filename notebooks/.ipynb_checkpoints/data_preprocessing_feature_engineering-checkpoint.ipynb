# %% [markdown]
# # Customer Lifetime Value — Data Cleaning, Preprocessing & Feature Engineering
#
# This notebook walks through the full data-prep pipeline used by the CLV Predictor app, self-contained and independent of Supabase/Docker:
#
# 1. Load raw data
# 2. Data cleaning (nulls, duplicates, dtypes, text normalization)
# 3. Exploratory checks
# 4. Feature engineering (`customer_lifetime_value` target)
# 5. Preprocessing pipeline (scaling + one-hot encoding)
# 6. Save processed data & the fitted preprocessor to `artifacts/`

# %%
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Load Raw Data

# %%
DATA_PATH = "../data/customer_transactions.csv"
df = pd.read_csv(DATA_PATH)

print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (10000, 8)
#   customer_id invoice_id invoice_date  purchase_amount product_category  \
# 0    CUST_102      INV_0   2024-01-23            71.39         Clothing
# 1    CUST_435      INV_1   2024-02-23            56.88         Clothing
# 2    CUST_860      INV_2   2024-03-05            89.96      Electronics
# 3    CUST_270      INV_3   2024-05-19            26.58           Beauty
# 4    CUST_106      INV_4   2024-01-24           283.46            Books
#
#      payment_method customer_segment region
# 0               UPI            Loyal  North
# 1       Credit Card        Returning  South
# 2  Cash on Delivery            Loyal   East
# 3  Cash on Delivery              New  South
# 4       Credit Card        Returning  North

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  str
#  1   invoice_id        10000 non-null  str
#  2   invoice_date      10000 non-null  str
#  3   purchase_amount   10000 non-null  float64
#  4   product_category  10000 non-null  str
#  5   payment_method    10000 non-null  str
#  6   customer_segment  10000 non-null  str
#  7   region            10000 non-null  str
# dtypes: float64(1), str(7)
# memory usage: 1.1 MB

# %% [markdown]
# ## 2. Data Cleaning
#
# Check and handle:
# - Missing values
# - Duplicate rows
# - Data types (dates, numerics)
# - Text normalization (casing/whitespace on categorical columns)
# - Basic sanity bounds on `purchase_amount`

# %%
# Missing values
missing = df.isnull().sum()
print("Missing values per column:")
print(missing[missing > 0] if missing.sum() > 0 else "No missing values found.")
# Out:
# Missing values per column:
# No missing values found.

# %%
# Duplicate rows
n_dupes = df.duplicated().sum()
print(f"Duplicate rows: {n_dupes}")

df = df.drop_duplicates().reset_index(drop=True)
print(f"Shape after dropping duplicates: {df.shape}")
# Out:
# Duplicate rows: 0
# Shape after dropping duplicates: (10000, 8)

# %%
# Drop rows missing critical fields (id, amount) - adjust threshold as needed
critical_cols = ["customer_id", "invoice_id", "purchase_amount"]
before = df.shape[0]
df = df.dropna(subset=critical_cols)
print(f"Dropped {before - df.shape[0]} rows missing critical fields.")

# For remaining categorical nulls, fill with 'unknown' rather than dropping
categorical_cols = ["product_category", "payment_method", "customer_segment", "region"]
for col in categorical_cols:
    if df[col].isnull().any():
        df[col] = df[col].fillna("unknown")
# Out:
# Dropped 0 rows missing critical fields.

# %%
# Data types
df["invoice_date"] = pd.to_datetime(df["invoice_date"], errors="coerce")
df["purchase_amount"] = pd.to_numeric(df["purchase_amount"], errors="coerce")

# Drop any rows where coercion failed
before = df.shape[0]
df = df.dropna(subset=["invoice_date", "purchase_amount"])
print(f"Dropped {before - df.shape[0]} rows with invalid date/amount.")
# Out:
# Dropped 0 rows with invalid date/amount.

# %%
# Normalize text columns: strip whitespace, lowercase
for col in categorical_cols:
    df[col] = df[col].astype(str).str.strip().str.lower()

df[categorical_cols].nunique()
# Out:
# product_category    5
# payment_method      4
# customer_segment    3
# region              4
# dtype: int64

# %%
# Sanity check: negative or zero purchase amounts are almost certainly bad data
invalid_amounts = (df["purchase_amount"] <= 0).sum()
print(f"Non-positive purchase amounts: {invalid_amounts}")

df = df[df["purchase_amount"] > 0].reset_index(drop=True)

# Basic outlier check with IQR (informational only, no rows dropped here)
q1, q3 = df["purchase_amount"].quantile([0.25, 0.75])
iqr = q3 - q1
upper_bound = q3 + 1.5 * iqr
n_outliers = (df["purchase_amount"] > upper_bound).sum()
print(f"Purchase amounts above IQR upper bound ({upper_bound:.2f}): {n_outliers} "
      f"({n_outliers/len(df):.1%}) — kept, since high spenders are meaningful for CLV.")
# Out:
# Non-positive purchase amounts: 1
# Purchase amounts above IQR upper bound (307.52): 501 (5.0%) — kept, since high spenders are meaningful for CLV.

# %%
print(f"Final cleaned shape: {df.shape}")
df.describe(include='all').T
# Out:
# Final cleaned shape: (9999, 8)
#                    count unique         top  freq                        mean  \
# customer_id         9999   1000    CUST_725    22                         NaN
# invoice_id          9999   9999       INV_0     1                         NaN
# invoice_date        9999    NaN         NaN   NaN  2024-03-29 11:15:17.011701
# purchase_amount   9999.0    NaN         NaN   NaN                  102.221921
# product_category    9999      5       books  2096                         NaN
# payment_method      9999      4  debit card  2591                         NaN
# customer_segment    9999      3         new  3360                         NaN
# region              9999      4       north  2534                         NaN
#
#                                   min                  25%  \
# customer_id                       NaN                  NaN
# invoice_id                        NaN                  NaN
# invoice_date      2024-01-01 00:00:00  2024-02-14 00:00:00
# purchase_amount                  0.03               29.605
# product_category                  NaN                  NaN
# payment_method                    NaN                  NaN
# customer_segment                  NaN                  NaN
# region                            NaN                  NaN
#
#                                   50%                  75%  \
# customer_id                       NaN                  NaN
# invoice_id                        NaN                  NaN
# invoice_date      2024-03-28 00:00:00  2024-05-13 00:00:00
# purchase_amount                 70.96               140.77
# product_category                  NaN                  NaN
# payment_method                    NaN                  NaN
# customer_segment                  NaN                  NaN
# region                            NaN                  NaN
#
#                                   max       std
# customer_id                       NaN       NaN
# invoice_id                        NaN       NaN
# invoice_date      2024-06-28 00:00:00       NaN
# purchase_amount                949.57  102.4977
# product_category                  NaN       NaN
# payment_method                    NaN       NaN
# customer_segment                  NaN       NaN
# region                            NaN       NaN

# %% [markdown]
# ## 3. Exploratory Checks
#
# Quick sanity plots before feature engineering.

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

df["purchase_amount"].hist(bins=40, ax=axes[0])
axes[0].set_title("Purchase Amount Distribution")
axes[0].set_xlabel("purchase_amount")

df["product_category"].value_counts().plot(kind="bar", ax=axes[1])
axes[1].set_title("Transactions by Product Category")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Feature Engineering
#
# Build the modeling target: **`customer_lifetime_value`** = total historical spend per customer.
#
# This mirrors `src/feature_engineering.py`'s `FeatureEngineer.add_clv_feature`.

# %%
def add_clv_feature(data: pd.DataFrame) -> pd.DataFrame:
    """Adds 'customer_lifetime_value' as total purchase amount per customer."""
    clv = data.groupby("customer_id")["purchase_amount"].sum().reset_index()
    clv = clv.rename(columns={"purchase_amount": "customer_lifetime_value"})
    return data.merge(clv, on="customer_id", how="left")

df_fe = add_clv_feature(df)
df_fe[["customer_id", "purchase_amount", "customer_lifetime_value"]].head()
# Out:
#   customer_id  purchase_amount  customer_lifetime_value
# 0    CUST_102            71.39                  1174.56
# 1    CUST_435            56.88                   852.01
# 2    CUST_860            89.96                   859.32
# 3    CUST_270            26.58                   965.77
# 4    CUST_106           283.46                  1046.54

# %%
df_fe["customer_lifetime_value"].describe()
# Out:
# count    9999.000000
# mean     1135.335952
# std       483.667359
# min        91.220000
# 25%       779.640000
# 50%      1091.960000
# 75%      1420.050000
# max      3131.330000
# Name: customer_lifetime_value, dtype: float64

# %% [markdown]
# Optional extra features that are commonly useful for CLV modeling (not required by the current model, but handy if you extend it later):
# - `purchase_count` — number of transactions per customer
# - `avg_purchase_amount` — mean spend per transaction
# - `customer_tenure_days` — days between first and last purchase

# %%
agg = df_fe.groupby("customer_id").agg(
    purchase_count=("invoice_id", "count"),
    avg_purchase_amount=("purchase_amount", "mean"),
    first_purchase=("invoice_date", "min"),
    last_purchase=("invoice_date", "max"),
).reset_index()
agg["customer_tenure_days"] = (agg["last_purchase"] - agg["first_purchase"]).dt.days

df_fe = df_fe.merge(
    agg[["customer_id", "purchase_count", "avg_purchase_amount", "customer_tenure_days"]],
    on="customer_id",
    how="left"
)

df_fe.head()
# Out:
#   customer_id invoice_id invoice_date  purchase_amount product_category  \
# 0    CUST_102      INV_0   2024-01-23            71.39         clothing
# 1    CUST_435      INV_1   2024-02-23            56.88         clothing
# 2    CUST_860      INV_2   2024-03-05            89.96      electronics
# 3    CUST_270      INV_3   2024-05-19            26.58           beauty
# 4    CUST_106      INV_4   2024-01-24           283.46            books
#
#      payment_method customer_segment region  customer_lifetime_value  \
# 0               upi            loyal  north                  1174.56
# 1       credit card        returning  south                   852.01
# 2  cash on delivery            loyal   east                   859.32
# 3  cash on delivery              new  south                   965.77
# 4       credit card        returning  north                  1046.54
#
#    purchase_count  avg_purchase_amount  customer_tenure_days
# 0               8           146.820000                   153
# 1              12            71.000833                   173
# 2               9            95.480000                   148
# 3              12            80.480833                   160
# 4               8           130.817500                   138

# %% [markdown]
# ## 5. Preprocessing Pipeline
#
# Same structure as `src/preprocessor.py`:
# - `purchase_amount` passed through (numeric, already clean)
# - Categorical columns one-hot encoded
#
# This is the exact transformer the Streamlit app's model expects at inference time.

# %%
numeric_features = ["purchase_amount"]
categorical_features = ["product_category", "payment_method", "customer_segment", "region"]

preprocessor = ColumnTransformer(transformers=[
    ("num", "passthrough", numeric_features),
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
])

X = df_fe[numeric_features + categorical_features]
X_transformed = preprocessor.fit_transform(X)

print(f"Transformed feature matrix shape: {X_transformed.shape}")
# Out:
# Transformed feature matrix shape: (9999, 17)

# %%
# Inspect the generated one-hot feature names
feature_names = (
    numeric_features
    + list(preprocessor.named_transformers_["cat"].get_feature_names_out(categorical_features))
)
print(f"Total features after encoding: {len(feature_names)}")
feature_names
# Out:
# Total features after encoding: 17
# ['purchase_amount',
#  'product_category_beauty',
#  'product_category_books',
#  'product_category_clothing',
#  'product_category_electronics',
#  'product_category_home',
#  'payment_method_cash on delivery',
#  'payment_method_credit card',
#  'payment_method_debit card',
#  'payment_method_upi',
#  'customer_segment_loyal',
#  'customer_segment_new',
#  'customer_segment_returning',
#  'region_east',
#  'region_north',
#  'region_south',
#  'region_west']

# %% [markdown]
# ## 6. Save Outputs
#
# Save the cleaned + feature-engineered dataset and the fitted preprocessor to `artifacts/`, matching what the Streamlit app loads at runtime.

# %%
os.makedirs("../artifacts", exist_ok=True)

# Cleaned + feature-engineered dataset (handy for retraining or analysis)
df_fe.to_csv("../artifacts/clv_features.csv", index=False)

# Fitted preprocessor (overwrite only if you intend to retrain the model on this data too,
# since the existing model.pkl was trained against the current preprocessor.pkl)
# joblib.dump(preprocessor, "../artifacts/preprocessor.pkl")

print("Saved cleaned + feature-engineered dataset to ../artifacts/clv_features.csv")
# Out:
# Saved cleaned + feature-engineered dataset to ../artifacts/clv_features.csv

# %% [markdown]
# > **Note:** The line that overwrites `preprocessor.pkl` is commented out on purpose — the model
# > artifact already shipped with this project (`artifacts/model.pkl`) was trained against the existing
# > `preprocessor.pkl`. If you retrain the model on this newly engineered data, uncomment that line
# > **and** retrain `model.pkl` in the same run so the two stay in sync.
